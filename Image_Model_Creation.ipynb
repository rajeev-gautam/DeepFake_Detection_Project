mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dsndhujjjb.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/aelfnikyqj.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/ddjggcasdw.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bqqpbzjgup.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dhevettufk.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bmjzrlszhi.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/duvyaxbzvp.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cpjxareypw.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/esckbnkkvb.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cferslmfwh.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/doanjploai.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/eggbjzxnmg.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/drgjzlxzxj.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dbhoxkblzx.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/esyhwdfnxs.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/eepezmygaq.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/etdcqxabww.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bmehkyanbj.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/azpuxunqyo.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/ccmonzqfrz.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bnjcdrfuov.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cizlkenljw.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bdbhekrrwo.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bdxuhamuqx.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/acifjvzvpm.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dzvyfiarrq.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/ebywfrmhtd.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/etejaapnxh.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/beboztfcme.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bsfmwclnqy.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cyboodqqyr.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bnbuonyoje.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/ehevsxtecd.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dbhrpizyeq.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dqppxmoqdl.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/edyncaijwx.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dsjbknkujw.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/amowujxmzc.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/aevrfsexku.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/deyyistcrd.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/asdpeebotb.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bqdjzqhcft.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dxuplhwvig.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/ajwpjhrbcv.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/dbtbbhakdv.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bvgwelbeof.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bydaidkpdp.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bilnggbxgu.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cknyxaqouy.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cgvrgibpfo.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/czmqpxrqoh.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/adohikbdaz.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/ehbnclaukr.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/czfunozvwp.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/djvutyvaio.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/ensyyivobf.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/bkmdzhfzfh.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/amaivqofda.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cdyakrxkia.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/cksanfsjhc.mp4
# /kaggle/input/competitions/deepfake-detection-challenge/train_sample_videos/drsakwyvqv.mp4

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2026-03-03 11:43:19.117759: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:467] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1772538199.306078      55 cuda_dnn.cc:8579] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1772538199.359408      55 cuda_blas.cc:1407] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# W0000 00:00:1772538199.772817      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772538199.772851      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772538199.772853      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# W0000 00:00:1772538199.772856      55 computation_placer.cc:177] computation placer already registered. Please check linkage and avoid linking the same target more than once.
# 2.19.0

# %%
import sys
import sklearn
import tensorflow as tf

import cv2
import pandas as pd
import numpy as np

import plotly.graph_objs as go
from plotly.offline import iplot
from matplotlib import pyplot as plt

# %%
tf.test.is_gpu_available()
# Out:
# WARNING:tensorflow:From /tmp/ipykernel_55/337460670.py:1: is_gpu_available (from tensorflow.python.framework.test_util) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use `tf.config.list_physical_devices('GPU')` instead.
# I0000 00:00:1772538228.852563      55 gpu_device.cc:2019] Created device /device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# True
# I0000 00:00:1772538228.856585      55 gpu_device.cc:2019] Created device /device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
tf.__version__
# Out:
# '2.19.0'

# %%
import matplotlib.pyplot as plt

plt.rc('font', size=14)
plt.rc('axes', labelsize=14, titlesize=14)
plt.rc('legend', fontsize=14)
plt.rc('xtick', labelsize=10)
plt.rc('ytick', labelsize=10)

# %%
import os

def get_data():
    return pd.read_csv('../input/datasets/dagnelies/deepfake-faces/metadata.csv')

# %%
meta=get_data()
meta.head()
# Out:
#         videoname  original_width  original_height label        original
# 0  aznyksihgl.mp4             129              129  FAKE  xnojggkrxt.mp4
# 1  gkwmalrvcj.mp4             129              129  FAKE  hqqmtxvbjj.mp4
# 2  lxnqzocgaq.mp4             223              217  FAKE  xjzkfqddyk.mp4
# 3  itsbtrrelv.mp4             186              186  FAKE  kqvepwqxfe.mp4
# 4  ddvgrczjno.mp4             155              155  FAKE  pluadmqqta.mp4

# %%
meta.shape
# Out:
# (95634, 5)

# %%
len(meta[meta.label=='FAKE']),len(meta[meta.label=='REAL'])
# Out:
# (79341, 16293)

# %%
real_df = meta[meta["label"] == "REAL"]
fake_df = meta[meta["label"] == "FAKE"]
sample_size = 8000

real_df = real_df.sample(sample_size, random_state=42)
fake_df = fake_df.sample(sample_size, random_state=42)

sample_meta = pd.concat([real_df, fake_df])

# %%
from sklearn.model_selection import train_test_split

Train_set, Test_set = train_test_split(sample_meta,test_size=0.2,random_state=42,stratify=sample_meta['label'])
Train_set, Val_set  = train_test_split(Train_set,test_size=0.3,random_state=42,stratify=Train_set['label'])

# %%
Train_set.shape,Val_set.shape,Test_set.shape
# Out:
# ((8960, 5), (3840, 5), (3200, 5))

# %%
y = dict()

y[0] = []
y[1] = []

for set_name in (np.array(Train_set['label']), np.array(Val_set['label']), np.array(Test_set['label'])):
    y[0].append(np.sum(set_name == 'REAL'))
    y[1].append(np.sum(set_name == 'FAKE'))

trace0 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[0],
    name='REAL',
    marker=dict(color='#33cc33'),
    opacity=0.7
)
trace1 = go.Bar(
    x=['Train Set', 'Validation Set', 'Test Set'],
    y=y[1],
    name='FAKE',
    marker=dict(color='#ff3300'),
    opacity=0.7
)

data = [trace0, trace1]
layout = go.Layout(
    title='Count of classes in each set',
    xaxis={'title': 'Set'},
    yaxis={'title': 'Count'}
)

fig = go.Figure(data, layout)
iplot(fig)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="a907a75a-03dd-492b-ae98-35523a2d37a2" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a907a75a-03dd-492b-ae98-35523a2d37a2")) {                    Plotly.newPlot(                        "a907a75a-03dd-492b-ae98-35523a2d37a2",                        [{"marker":{"color":"#33cc33"},"name":"REAL","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[4480,1920,1600],"type":"bar"},{"marker":{"color":"#ff3300"},"name":"FAKE","opacity":0.7,"x":["Train Set","Validation Set","Test Set"],"y":[4480,1920,1600],"type":"bar"}],                        {"template":{"data":{"barpolar":[{"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"barpolar"}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"carpet":[{"aaxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"baxis":{"endlinecolor":"#2a3f5f","gridcolor":"white","linecolor":"white","minorgridcolor":"white","startlinecolor":"#2a3f5f"},"type":"carpet"}],"choropleth":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"choropleth"}],"contourcarpet":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"contourcarpet"}],"contour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"contour"}],"heatmapgl":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmapgl"}],"heatmap":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"heatmap"}],"histogram2dcontour":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2dcontour"}],"histogram2d":[{"colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]],"type":"histogram2d"}],"histogram":[{"marker":{"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"histogram"}],"mesh3d":[{"colorbar":{"outlinewidth":0,"ticks":""},"type":"mesh3d"}],"parcoords":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"parcoords"}],"pie":[{"automargin":true,"type":"pie"}],"scatter3d":[{"line":{"colorbar":{"outlinewidth":0,"ticks":""}},"marker":{"colorbar":{"outlinewidth":0,"ticks":""}},"type":"scatter3d"}],"scattercarpet":[{"marker":{" ...

# %%
plt.figure(figsize=(15,15))
for cur,i in enumerate(Train_set.index[25:50]):
    plt.subplot(5,5,cur+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)

    plt.imshow(cv2.imread('../input/datasets/dagnelies/deepfake-faces/faces_224/'+Train_set.loc[i,'videoname'][:-4]+'.jpg'))

    if(Train_set.loc[i,'label']=='FAKE'):
        plt.xlabel('FAKE Image')
    else:
        plt.xlabel('REAL Image')

plt.show()

# %%
def retreive_dataset(set_name):
    images,labels=[],[]
    for (img, imclass) in zip(set_name['videoname'], set_name['label']):
        images.append(cv2.imread('../input/datasets/dagnelies/deepfake-faces/faces_224/'+img[:-4]+'.jpg'))
        if(imclass=='FAKE'):
            labels.append(1)
        else:
            labels.append(0)

    return np.array(images),np.array(labels)

# %%
X_train,y_train=retreive_dataset(Train_set)
X_val,y_val=retreive_dataset(Val_set)
X_test,y_test=retreive_dataset(Test_set)

# %%
from functools import partial

tf.random.set_seed(42)
DefaultConv2D = partial(tf.keras.layers.Conv2D, kernel_size=3, padding="same",
                        activation="relu", kernel_initializer="he_normal")

model = tf.keras.Sequential([
    DefaultConv2D(filters=64, kernel_size=7, input_shape=[224, 224, 3]),
    tf.keras.layers.MaxPool2D(),
    DefaultConv2D(filters=128),
    DefaultConv2D(filters=128),
    tf.keras.layers.MaxPool2D(),
    tf.keras.layers.Flatten(),
    tf.keras.layers.Dense(units=128, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=64, activation="relu",
                          kernel_initializer="he_normal"),
    tf.keras.layers.Dropout(0.5),
    tf.keras.layers.Dense(units=1, activation="sigmoid")
])
# Out:
# /usr/local/lib/python3.12/dist-packages/keras/src/layers/convolutional/base_conv.py:113: UserWarning:
#
# Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#
# I0000 00:00:1772538401.811614      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 13757 MB memory:  -> device: 0, name: Tesla T4, pci bus id: 0000:00:04.0, compute capability: 7.5
# I0000 00:00:1772538401.813045      55 gpu_device.cc:2019] Created device /job:localhost/replica:0/task:0/device:GPU:1 with 13757 MB memory:  -> device: 1, name: Tesla T4, pci bus id: 0000:00:05.0, compute capability: 7.5

# %%
model.compile(loss="binary_crossentropy", optimizer="nadam",
              metrics=["accuracy"])
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                 │ (None, 224, 224, 64)   │         9,472 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d (MaxPooling2D)    │ (None, 112, 112, 64)   │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_1 (Conv2D)               │ (None, 112, 112, 128)  │        73,856 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv2d_2 (Conv2D)               │ (None, 112, 112, 128)  │       147,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling2d_1 (MaxPooling2D)  │ (None, 56, 56, 128)    │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ flatten (Flatten)               │ (None, 401408)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 128)            │    51,380,352 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            65 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 51,619,585 (196.91 MB)
#  Trainable params: 51,619,585 (196.91 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
history = model.fit(X_train, y_train, epochs=5,batch_size=64,
                    validation_data=(X_val, y_val))
# Out:
# Epoch 1/5
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1772538419.996022     126 service.cc:152] XLA service 0x7f632c00d6f0 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1772538419.996060     126 service.cc:160]   StreamExecutor device (0): Tesla T4, Compute Capability 7.5
# I0000 00:00:1772538419.996064     126 service.cc:160]   StreamExecutor device (1): Tesla T4, Compute Capability 7.5
# I0000 00:00:1772538420.455978     126 cuda_dnn.cc:529] Loaded cuDNN version 91002
# 2026-03-03 11:47:10.438679: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:47:10.665272: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:47:14.113178: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:47:14.306176: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# I0000 00:00:1772538445.222751     126 device_compiler.h:188] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 87s 423ms/step - accuracy: 0.4997 - loss: 1404.6471 - val_accuracy: 0.4953 - val_loss: 0.6936
# Epoch 2/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 49s 347ms/step - accuracy: 0.5030 - loss: 0.6936 - val_accuracy: 0.4940 - val_loss: 0.6933
# Epoch 3/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 49s 351ms/step - accuracy: 0.5202 - loss: 0.6930 - val_accuracy: 0.4977 - val_loss: 0.6941
# Epoch 4/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 49s 349ms/step - accuracy: 0.5027 - loss: 0.7031 - val_accuracy: 0.5010 - val_loss: 0.6933
# Epoch 5/5
# 140/140 ━━━━━━━━━━━━━━━━━━━━ 49s 349ms/step - accuracy: 0.4988 - loss: 0.6934 - val_accuracy: 0.4930 - val_loss: 0.7230

# %%
score = model.evaluate(X_test, y_test)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 10s 49ms/step - accuracy: 0.4785 - loss: 0.7256

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
train_set_raw=tf.data.Dataset.from_tensor_slices((X_train,y_train))
valid_set_raw=tf.data.Dataset.from_tensor_slices((X_val,y_val))
test_set_raw=tf.data.Dataset.from_tensor_slices((X_test,y_test))

# %%
tf.keras.backend.clear_session()  # extra code – resets layer name counter

batch_size = 32
preprocess = tf.keras.applications.xception.preprocess_input
train_set = train_set_raw.map(lambda X, y: (preprocess(tf.cast(X, tf.float32)), y))
train_set = train_set.shuffle(1000, seed=42).batch(batch_size).prefetch(1)
valid_set = valid_set_raw.map(lambda X, y: (preprocess(tf.cast(X, tf.float32)), y)).batch(batch_size)
test_set = test_set_raw.map(lambda X, y: (preprocess(tf.cast(X, tf.float32)), y)).batch(batch_size)

# %%
# extra code – displays the first 9 images in the first batch of valid_set

plt.figure(figsize=(12, 12))
for X_batch, y_batch in valid_set.take(1):
    for index in range(9):
        plt.subplot(3, 3, index + 1)
        plt.imshow((X_batch[index] + 1) / 2)  # rescale to 0–1 for imshow()
        if(y_batch[index]==1):
            classt='FAKE'
        else:
            classt='REAL'
        plt.title(f"Class: {classt}")
        plt.axis("off")

plt.show()

# %%
data_augmentation = tf.keras.Sequential([
    tf.keras.layers.RandomFlip(mode="horizontal", seed=42),
    tf.keras.layers.RandomRotation(factor=0.05, seed=42),
    tf.keras.layers.RandomContrast(factor=0.2, seed=42)
])

# %%
# extra code – displays the same first 9 images, after augmentation

plt.figure(figsize=(12, 12))
for X_batch, y_batch in valid_set.take(1):
    X_batch_augmented = data_augmentation(X_batch, training=True)
    for index in range(9):
        plt.subplot(3, 3, index + 1)
        # We must rescale the images to the 0-1 range for imshow(), and also
        # clip the result to that range, because data augmentation may
        # make some values go out of bounds (e.g., RandomContrast in this case).
        plt.imshow(np.clip((X_batch_augmented[index] + 1) / 2, 0, 1))
        if(y_batch[index]==1):
            classt='FAKE'
        else:
            classt='REAL'
        plt.title(f"Class: {classt}")
        plt.axis("off")

plt.show()

# %%
tf.random.set_seed(42)  # extra code – ensures reproducibility
base_model = tf.keras.applications.xception.Xception(weights="imagenet",
                                                     include_top=False)
avg = tf.keras.layers.GlobalAveragePooling2D()(base_model.output)
output = tf.keras.layers.Dense(1, activation="sigmoid")(avg)
model = tf.keras.Model(inputs=base_model.input, outputs=output)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/xception/xception_weights_tf_dim_ordering_tf_kernels_notop.h5
# 83683744/83683744 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
for layer in base_model.layers:
    layer.trainable = False

# %%
from tensorflow.keras.callbacks import EarlyStopping
optimizer = tf.keras.optimizers.SGD(learning_rate=0.1, momentum=0.9)
model.compile(loss="binary_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
early_stop = EarlyStopping(
    monitor='val_accuracy',
    patience=3,
    restore_best_weights=True
)
history = model.fit(train_set, validation_data=valid_set, epochs=10, callbacks=[early_stop])
# Out:
# Epoch 1/10
# 2026-03-03 11:53:49.933275: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:50.121769: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:52.860038: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:53.003319: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:54.472179: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:54.614487: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:54.752956: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:55.538118: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 11:53:55.687324: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 89s 239ms/step - accuracy: 0.5676 - loss: 0.8971 - val_accuracy: 0.5648 - val_loss: 1.4604
# Epoch 2/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 63s 223ms/step - accuracy: 0.6125 - loss: 0.8886 - val_accuracy: 0.6193 - val_loss: 0.8891
# Epoch 3/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 62s 222ms/step - accuracy: 0.6363 - loss: 0.8694 - val_accuracy: 0.6250 - val_loss: 0.8682
# Epoch 4/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 62s 221ms/step - accuracy: 0.6303 - loss: 0.8916 - val_accuracy: 0.5544 - val_loss: 1.5449
# Epoch 5/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 62s 221ms/step - accuracy: 0.6203 - loss: 0.9914 - val_accuracy: 0.6547 - val_loss: 0.7002
# Epoch 6/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 62s 220ms/step - accuracy: 0.6463 - loss: 0.8834 - val_accuracy: 0.6643 - val_loss: 0.7077
# Epoch 7/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 62s 221ms/step - accuracy: 0.6754 - loss: 0.7586 - val_accuracy: 0.5979 - val_loss: 1.0554
# Epoch 8/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 62s 222ms/step - accuracy: 0.6451 - loss: 0.9020 - val_accuracy: 0.6510 - val_loss: 0.7937
# Epoch 9/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 62s 221ms/step - accuracy: 0.6784 - loss: 0.7533 - val_accuracy: 0.6031 - val_loss: 0.9124

# %%
for indices in zip(range(33), range(33, 66), range(66, 99), range(99, 132)):
    for idx in indices:
        print(f"{idx:3}: {base_model.layers[idx].name:22}", end="")
    print()
# Out:
#   0: input_layer_1          33: block4_pool            66: block8_sepconv1_act    99: block11_sepconv2_act
#   1: block1_conv1           34: batch_normalization_2  67: block8_sepconv1       100: block11_sepconv2
#   2: block1_conv1_bn        35: add_2                  68: block8_sepconv1_bn    101: block11_sepconv2_bn
#   3: block1_conv1_act       36: block5_sepconv1_act    69: block8_sepconv2_act   102: block11_sepconv3_act
#   4: block1_conv2           37: block5_sepconv1        70: block8_sepconv2       103: block11_sepconv3
#   5: block1_conv2_bn        38: block5_sepconv1_bn     71: block8_sepconv2_bn    104: block11_sepconv3_bn
#   6: block1_conv2_act       39: block5_sepconv2_act    72: block8_sepconv3_act   105: add_9
#   7: block2_sepconv1        40: block5_sepconv2        73: block8_sepconv3       106: block12_sepconv1_act
#   8: block2_sepconv1_bn     41: block5_sepconv2_bn     74: block8_sepconv3_bn    107: block12_sepconv1
#   9: block2_sepconv2_act    42: block5_sepconv3_act    75: add_6                 108: block12_sepconv1_bn
#  10: block2_sepconv2        43: block5_sepconv3        76: block9_sepconv1_act   109: block12_sepconv2_act
#  11: block2_sepconv2_bn     44: block5_sepconv3_bn     77: block9_sepconv1       110: block12_sepconv2
#  12: conv2d                 45: add_3                  78: block9_sepconv1_bn    111: block12_sepconv2_bn
#  13: block2_pool            46: block6_sepconv1_act    79: block9_sepconv2_act   112: block12_sepconv3_act
#  14: batch_normalization    47: block6_sepconv1        80: block9_sepconv2       113: block12_sepconv3
#  15: add                    48: block6_sepconv1_bn     81: block9_sepconv2_bn    114: block12_sepconv3_bn
#  16: block3_sepconv1_act    49: block6_sepconv2_act    82: block9_sepconv3_act   115: add_10
#  17: block3_sepconv1        50: block6_sepconv2        83: block9_sepconv3       116: block13_sepconv1_act
#  18: block3_sepconv1_bn     51: block6_sepconv2_bn     84: block9_sepconv3_bn    117: block13_sepconv1
#  19: block3_sepconv2_act    52: block6_sepconv3_act    85: add_7                 118: block13_sepconv1_bn
#  20: block3_sepconv2        53: block6_sepconv3        86: block10_sepconv1_act  119: block13_sepconv2_act
#  21: block3_sepconv2_bn     54: block6_sepconv3_bn     87: block10_sepconv1      120: block13_sepconv2
#  22: conv2d_1               55: add_4                  88: block10_sepconv1_bn   121: block13_sepconv2_bn
#  23: block3_pool            56: block7_sepconv1_act    89: block10_sepconv2_act  122: conv2d_3
#  24: batch_normalization_1  57: block7_sepconv1        90: block10_sepconv2      123: block13_pool
#  25: add_1                  58: block7_sepconv1_bn     91: block10_sepconv2_bn   124: batch_normalization_3
#  26: block4_sepconv1_act    59: block7_sepconv2_act    92: block10_sepconv3_act  125: add_11
#  27: block4_sepconv1        60: block7_sepconv2        93: block10_sepconv3      126: block14_sepconv1
#  28: block4_sepconv1_bn     61: block7_sepconv2_bn     94: block10_sepconv3_bn   127: block14_sepconv1_bn
#  29: block4_sepconv2_act    62: block7_sepconv3_act    95: add_8                 128: block14_sepconv1_act
#  30: block4_sepconv2        63: block7_sepconv3        96: block11_sepconv1_act  129: block14_sepconv2
#  31: block4_sepconv2_bn     64: block7_sepconv3_bn     97: block11_sepconv1      130: block14_sepconv2_bn
#  32: conv2d_2               65: add_5                  98: block11_sepconv1_bn   131: block14_sepconv2_act

# %%
model.evaluate(test_set)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 16s 157ms/step - accuracy: 0.6797 - loss: 0.6942
# [0.7145623564720154, 0.6634374856948853]

# %%
for layer in base_model.layers[56:]:
    layer.trainable = True

optimizer = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9)
model.compile(loss="binary_crossentropy", optimizer=optimizer,
              metrics=["accuracy"])
history = model.fit(train_set, validation_data=valid_set, epochs=10)
# Out:
# Epoch 1/10
# 2026-03-03 12:07:28.072786: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 2026-03-03 12:07:28.213386: E external/local_xla/xla/stream_executor/cuda/cuda_timer.cc:86] Delay kernel timed out: measured time has sub-optimal accuracy. There may be a missing warmup execution, please investigate in Nsight Systems.
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 137s 419ms/step - accuracy: 0.5953 - loss: 0.6914 - val_accuracy: 0.7427 - val_loss: 0.5187
# Epoch 2/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 398ms/step - accuracy: 0.8311 - loss: 0.3758 - val_accuracy: 0.7602 - val_loss: 0.5898
# Epoch 3/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 400ms/step - accuracy: 0.9372 - loss: 0.1691 - val_accuracy: 0.6914 - val_loss: 1.1438
# Epoch 4/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 400ms/step - accuracy: 0.9552 - loss: 0.1238 - val_accuracy: 0.7948 - val_loss: 0.5974
# Epoch 5/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 401ms/step - accuracy: 0.9651 - loss: 0.0921 - val_accuracy: 0.7625 - val_loss: 0.9145
# Epoch 6/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 399ms/step - accuracy: 0.9811 - loss: 0.0569 - val_accuracy: 0.7943 - val_loss: 0.7846
# Epoch 7/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 398ms/step - accuracy: 0.9823 - loss: 0.0511 - val_accuracy: 0.8060 - val_loss: 0.7907
# Epoch 8/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 398ms/step - accuracy: 0.9860 - loss: 0.0422 - val_accuracy: 0.8034 - val_loss: 0.7958
# Epoch 9/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 398ms/step - accuracy: 0.9879 - loss: 0.0397 - val_accuracy: 0.8188 - val_loss: 0.6858
# Epoch 10/10
# 280/280 ━━━━━━━━━━━━━━━━━━━━ 112s 400ms/step - accuracy: 0.9915 - loss: 0.0263 - val_accuracy: 0.8083 - val_loss: 0.7201

# %%
# plot model performance
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']
loss = history.history['loss']
val_loss = history.history['val_loss']
epochs_range = range(1, len(history.epoch) + 1)

plt.figure(figsize=(15,5))

plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Train Set')
plt.plot(epochs_range, val_acc, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Accuracy')
plt.title('Model Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Train Set')
plt.plot(epochs_range, val_loss, label='Val Set')
plt.legend(loc="best")
plt.xlabel('Epochs')
plt.ylabel('Loss')
plt.title('Model Loss')

plt.tight_layout()
plt.show()

# %%
model.evaluate(test_set)
# Out:
# 100/100 ━━━━━━━━━━━━━━━━━━━━ 15s 154ms/step - accuracy: 0.8195 - loss: 0.6819
# [0.6538728475570679, 0.8178125023841858]

# %%
model.save('xception_deepfake_image.h5')
# Out:
# WARNING:absl:You are saving your model as an HDF5 file via `model.save()` or `keras.saving.save_model(model)`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')` or `keras.saving.save_model(model, 'my_model.keras')`.
